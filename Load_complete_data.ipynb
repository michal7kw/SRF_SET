# %% [markdown]
# # Load in R

# %%
# Essential packages
import scanpy as sc
import anndata as ad
import pandas as pd
import numpy as np
import scipy.sparse as sparse
import muon as mu  # specifically for multiome data
import matplotlib.pyplot as plt

# For reading R objects
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter

# For reading 10x HDF5 files
import h5py
import os

# %%
import rpy2
pandas2ri.activate()
# %load_ext rpy2.ipython

# %%
wd_dir = '/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SET/Multiome_SETBP1'
os.chdir(wd_dir)

# %%
# %%R
# load("/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SET/Multiome_SETBP1/Multiome_SETBP1/all/AGG_Setbp1/outs/Multiome.RData")
# ls()  #list all objects that were loaded
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
#      [1] "A"                   "A2"                  "all.genes"
#  [4] "Cluster"             "cluster.markers"     "clusters_coupe"
#  [7] "DGE_embryo_ctrl_mut" "DGE_P2_ctrl_mut"     "i"
# [10] "LogFC.onlypos"       "min.diff.pct"        "min.pct"
# [13] "mycol"               "N"                   "p1"
# [16] "p2"                  "p3"                  "pbmc_RNA"
# [19] "pbmc_RNA_prova"      "pbmc_umap_coord"     "PCA"
# [22] "test.use"            "thresh.use"          "top10"

# %%
# %%R
# pbmc_RNA
# Out:
# An object of class Seurat
# 24993 features across 34264 samples within 1 assay
# Active assay: RNA (24993 features, 0 variable features)
#  2 layers present: counts, data

# %%
# %%R
# # Load required libraries
# library(Seurat)
# library(ggplot2)
# library(dplyr)
# library(pheatmap)
# Out:
# Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching package: ‘SeuratObject’
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# In addition: Warning message:
# package ‘pheatmap’ was built under R version 4.4.1

# %%
# %%R
# # Basic information about RNA object
# print("RNA object information:")
# pbmc_RNA
# Out:
# [1] "RNA object information:"
# An object of class Seurat
# 24993 features across 34264 samples within 1 assay
# Active assay: RNA (24993 features, 0 variable features)
#  2 layers present: counts, data

# %%
# %%R
# print("Available reductions:")
# print(Reductions(pbmc_RNA))
# Out:
# [1] "Available reductions:"
# NULL

# %%
# %%R
# # For embryo samples
# head(DGE_embryo_ctrl_mut)
# Out:
#                p_val  avg_diff pct.1 pct.2     p_val_adj Gene_name
# Xist    0.000000e+00 -4.549018 0.227 0.870  0.000000e+00      Xist
# Tsix   9.366323e-280 -1.184269 0.166 0.636 2.340925e-275      Tsix
# Hbb-bs 5.653742e-242  2.375886 0.820 0.387 1.413040e-237    Hbb-bs
# Tmsb10 2.876233e-216  3.127081 0.940 0.691 7.188570e-212    Tmsb10
# Rps21  3.197631e-206  2.463274 0.903 0.643 7.991840e-202     Rps21
# Rpl37  3.932163e-191  2.409653 0.906 0.678 9.827655e-187     Rpl37

# %%
# %%R
# # For P2 samples
# head(DGE_P2_ctrl_mut)
# Out:
#          p_val  avg_diff pct.1 pct.2 p_val_adj Gene_name
# Mir99ahg     0  9.475910 0.986 0.964         0  Mir99ahg
# Grik2        0  4.446774 0.905 0.868         0     Grik2
# Hba-a1       0 -1.172631 0.396 0.652         0    Hba-a1
# Hbb-bs       0 -1.306164 0.568 0.815         0    Hbb-bs
# Dbi          0 -1.767954 0.830 0.954         0       Dbi
# Cmss1        0 -4.744029 0.802 0.935         0     Cmss1

# %%
# %%R
# # Check cluster markers
# head(cluster.markers)
# Out:
# [1] "Top markers per cluster:"
#         p_val avg_logFC pct.1 pct.2 p_val_adj cluster    gene
# Unc5d       0  1.748728 0.961 0.489         0       0   Unc5d
# Sema3c      0  1.571726 0.845 0.230         0       0  Sema3c
# Galnt17     0  1.350758 0.890 0.348         0       0 Galnt17
# Gramd1b     0  1.334421 0.902 0.421         0       0 Gramd1b
# Frmd4b      0  1.314171 0.967 0.612         0       0  Frmd4b
# Zfhx4       0  1.276921 0.837 0.365         0       0   Zfhx4

# %%
# %%R
# # ggsave("umap_clusters.pdf", p1, width = 10, height = 8)
# # ggsave("volcano_plot.pdf", p2, width = 10, height = 8)
# # ggsave("feature_plots.pdf", p3, width = 15, height = 10)

# %% [markdown]
# # Load in Python

# %%
import pandas as pd
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter

# %%
def load_rdata(rdata_path):
    """
    Load an RData file and convert it to Python objects
    """
    # Initialize R
    r = robjects.r
    
    # Load the RData file
    r['load'](rdata_path)
    
    # Get the names of objects in the R workspace
    r_objects = list(r['ls']())
    
    # Initialize dictionary to store converted objects
    converted_objects = {}
    
    # Convert each R object to Python
    with localconverter(robjects.default_converter + pandas2ri.converter):
        for obj_name in r_objects:
            r_obj = r[obj_name]
            
            try:
                # If object is already a pandas DataFrame or numpy array, store directly
                if isinstance(r_obj, (pd.DataFrame, np.ndarray)):
                    converted_objects[obj_name] = r_obj
                    continue
                
                # Handle Seurat objects specifically
                if isinstance(r_obj, robjects.methods.RS4):
                    converted_objects[obj_name] = r_obj
                    print(f"Stored Seurat object {obj_name} in original R format")
                    continue
                
                # Handle different R object types
                if isinstance(r_obj, (robjects.vectors.DataFrame, robjects.vectors.Matrix)):
                    converted_objects[obj_name] = pandas2ri.rpy2py(r_obj)
                elif isinstance(r_obj, robjects.vectors.Array):
                    converted_objects[obj_name] = np.array(r_obj)
                elif isinstance(r_obj, robjects.vectors.StrVector):
                    converted_objects[obj_name] = list(r_obj)
                elif isinstance(r_obj, robjects.vectors.FloatVector):
                    converted_objects[obj_name] = np.array(r_obj)
                elif isinstance(r_obj, robjects.vectors.BoolVector):
                    converted_objects[obj_name] = np.array(r_obj, dtype=bool)
                elif str(type(r_obj)).find('OrdDict') != -1:  # Check if it's an OrdDict without direct import
                    try:
                        # Convert OrdDict to regular dictionary
                        converted_objects[obj_name] = {str(k): v for k, v in r_obj.items()}
                    except AttributeError:
                        # If items() not available, store as is
                        converted_objects[obj_name] = r_obj
                else:
                    # Try general conversion
                    converted_objects[obj_name] = pandas2ri.rpy2py(r_obj)
                
            except Exception as e:
                print(f"Note: Could not convert object {obj_name}: {str(e)}")
                # Store the R object directly as fallback
                converted_objects[obj_name] = r_obj
    
    return converted_objects

# %%
rdata_path = "/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SET/Multiome_SETBP1/Multiome_SETBP1/all/AGG_Setbp1/outs/Multiome.RData"
data = load_rdata(rdata_path)

# Access converted objects
for obj_name, obj in data.items():
    print(f"Loaded object: {obj_name}, Type: {type(obj)}")
# Out:
# Stored Seurat object pbmc_RNA in original R format
# Stored Seurat object pbmc_RNA_prova in original R format
# Stored Seurat object pbmc_umap_coord in original R format
# Loaded object: A, Type: <class 'pandas.core.frame.DataFrame'>
# Loaded object: A2, Type: <class 'pandas.core.frame.DataFrame'>
# Loaded object: all.genes, Type: <class 'list'>
# Loaded object: Cluster, Type: <class 'pandas.core.frame.DataFrame'>
# Loaded object: cluster.markers, Type: <class 'pandas.core.frame.DataFrame'>
# Loaded object: clusters_coupe, Type: <class 'pandas.core.frame.DataFrame'>
# Loaded object: DGE_embryo_ctrl_mut, Type: <class 'pandas.core.frame.DataFrame'>
# Loaded object: DGE_P2_ctrl_mut, Type: <class 'pandas.core.frame.DataFrame'>
# Loaded object: i, Type: <class 'numpy.ndarray'>
# Loaded object: LogFC.onlypos, Type: <class 'numpy.ndarray'>
# Loaded object: min.diff.pct, Type: <class 'numpy.ndarray'>
# Loaded object: min.pct, Type: <class 'numpy.ndarray'>
# Loaded object: mycol, Type: <class 'list'>
# Loaded object: N, Type: <class 'dict'>
# Loaded object: p1, Type: <class 'dict'>
# Loaded object: p2, Type: <class 'dict'>
# Loaded object: p3, Type: <class 'dict'>
# Loaded object: p5, Type: <class 'dict'>
# Loaded object: pbmc_RNA, Type: <class 'rpy2.robjects.methods.RS4'>
# Loaded object: pbmc_RNA_prova, Type: <class 'rpy2.robjects.methods.RS4'>
# Loaded object: pbmc_umap_coord, Type: <class 'rpy2.robjects.methods.RS4'>
# Loaded object: PCA, Type: <class 'pandas.core.frame.DataFrame'>
# Loaded object: test.use, Type: <class 'list'>
# Loaded object: thresh.use, Type: <class 'numpy.ndarray'>
# Loaded object: top10, Type: <class 'pandas.core.frame.DataFrame'>

# %%
data.keys()
# Out:
# dict_keys(['A', 'A2', 'all.genes', 'Cluster', 'cluster.markers', 'clusters_coupe', 'DGE_embryo_ctrl_mut', 'DGE_P2_ctrl_mut', 'i', 'LogFC.onlypos', 'min.diff.pct', 'min.pct', 'mycol', 'N', 'p1', 'p2', 'p3', 'p5', 'pbmc_RNA', 'pbmc_RNA_prova', 'pbmc_umap_coord', 'PCA', 'test.use', 'thresh.use', 'top10'])

# %%
for key in data.keys():
    print(type(data[key]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'list'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'rpy2.robjects.methods.RS4'>
# <class 'rpy2.robjects.methods.RS4'>
# <class 'rpy2.robjects.methods.RS4'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'pandas.core.frame.DataFrame'>

# %%
for key in data.keys():
    print(f"\nKey: {key}")
    if type(data[key]) == pd.DataFrame:
        print("DataFrame:")
        print(data[key].head())
    elif type(data[key]) == np.ndarray:
        print("NumPy Array:")
        print(data[key][:10])
    elif type(data[key]) == list:
        print("List:")
        print(data[key][:10] if len(data[key]) > 10 else data[key])
    elif type(data[key]) == dict:
        print("Dictionary:")
        # Print first 5 key-value pairs
        for i, (k, v) in enumerate(data[key].items()):
            if i >= 5:
                break
            print(f"{k}: {v}")
    elif str(type(data[key])).find('RS4') != -1:
        print("R S4 Object")
        # print(str(data[key])[:200] + "..." if len(str(data[key])) > 200 else str(data[key]))
    else:
        print("Other type" )
        # print(f"Other type ({type(data[key])}:")
        # print(str(data[key])[:100])
# Out:
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
# /home/kubacki.michal/.conda/envs/jupyter_nb/lib/python3.11/site-packages/rpy2/robjects/robject.py:123: UserWarning: Invalid call to "show()" in R: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
#   warnings.warn(f'Invalid call to "show()" in R: {rre}')
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
# /home/kubacki.michal/.conda/envs/jupyter_nb/lib/python3.11/site-packages/rpy2/robjects/robject.py:123: UserWarning: Invalid call to "show()" in R: Error in print(..., self = self) : unused argument (useS4 = FALSE)
#
#   warnings.warn(f'Invalid call to "show()" in R: {rre}')
# R[write to console]: Error in print(..., self = self) : unused argument (useS4 = FALSE)
# Key: A
# DataFrame:
#           Var1   Freq
# 1  embryo_ctrl   1438
# 2   embryo_mut   5765
# 3      P2_ctrl  12276
# 4       P2_mut  11925
#
# Key: A2
# DataFrame:
#   Var1         Var2  Freq
# 1    0  embryo_ctrl    12
# 2    1  embryo_ctrl    26
# 3    2  embryo_ctrl   392
# 4    3  embryo_ctrl     1
# 5    4  embryo_ctrl    30
#
# Key: all.genes
# List:
# ['Xkr4', 'Gm1992', 'Gm19938', 'Gm37381', 'Rp1', 'Sox17', 'Gm37587', 'Gm37323', 'Mrpl15', 'Lypla1']
#
# Key: Cluster
# DataFrame:
#                    orig.ident  nCount_RNA  nFeature_RNA Condition  \
# AAACAGCCAACTGGGA-4        RNA      3573.0          1887    P2_mut
# AAACAGCCAAGGATTA-3        RNA      7486.0          3147   P2_ctrl
# AAACAGCCAAGTTATC-3        RNA      5815.0          2856   P2_ctrl
# AAACAGCCAATTGAGA-4        RNA      3482.0          1804    P2_mut
# AAACAGCCACCTCAGG-4        RNA      3919.0          1999    P2_mut
#
#                    RNA_snn_res.0.5  id             Barcode
# AAACAGCCAACTGGGA-4               0   0  AAACAGCCAACTGGGA-4
# AAACAGCCAAGGATTA-3              10  10  AAACAGCCAAGGATTA-3
# AAACAGCCAAGTTATC-3               4   4  AAACAGCCAAGTTATC-3
# AAACAGCCAATTGAGA-4               0   0  AAACAGCCAATTGAGA-4
# AAACAGCCACCTCAGG-4               0   0  AAACAGCCACCTCAGG-4
#
# Key: cluster.markers
# DataFrame:
#          p_val  avg_logFC  pct.1  pct.2  p_val_adj cluster     gene
# Unc5d      0.0   1.748728  0.961  0.489        0.0       0    Unc5d
# Sema3c     0.0   1.571726  0.845  0.230        0.0       0   Sema3c
# Galnt17    0.0   1.350758  0.890  0.348        0.0       0  Galnt17
# Gramd1b    0.0   1.334421  0.902  0.421        0.0       0  Gramd1b
# Frmd4b     0.0   1.314171  0.967  0.612        0.0       0   Frmd4b
#
# Key: clusters_coupe
# DataFrame:
#               Barcode  Cloupe_C
# 1  AAACAGCCAACTGGGA-4         1
# 2  AAACAGCCAAGGATTA-3         2
# 3  AAACAGCCAAGTTATC-3         2
# 4  AAACAGCCAATTGAGA-4         1
# 5  AAACAGCCACCTCAGG-4         1
#
# Key: DGE_embryo_ctrl_mut
# DataFrame:
#                 p_val  avg_diff  pct.1  pct.2      p_val_adj Gene_name
# Xist     0.000000e+00 -4.549018  0.227  0.870   0.000000e+00      Xist
# Tsix    9.366323e-280 -1.184269  0.166  0.636  2.340925e-275      Tsix
# Hbb-bs  5.653742e-242  2.375886  0.820  0.387  1.413040e-237    Hbb-bs
# Tmsb10  2.876233e-216  3.127081  0.940  0.691  7.188570e-212    Tmsb10
# Rps21   3.197631e-206  2.463274  0.903  0.643  7.991840e-202     Rps21
#
# Key: DGE_P2_ctrl_mut
# DataFrame:
#           p_val  avg_diff  pct.1  pct.2  p_val_adj Gene_name
# Mir99ahg    0.0  9.475910  0.986  0.964        0.0  Mir99ahg
# Grik2       0.0  4.446774  0.905  0.868        0.0     Grik2
# Hba-a1      0.0 -1.172631  0.396  0.652        0.0    Hba-a1
# Hbb-bs      0.0 -1.306164  0.568  0.815        0.0    Hbb-bs
# Dbi         0.0 -1.767954  0.830  0.954        0.0       Dbi
#
# Key: i
# NumPy Array:
# [1]
#
# Key: LogFC.onlypos
# NumPy Array:
# [ True]
#
# Key: min.diff.pct
# NumPy Array:
# [-inf]
#
# Key: min.pct
# NumPy Array:
# [0.25]
#
# Key: mycol
# List:
# ['#F2F3F4', '#222222', '#F3C300', '#875692', '#F38400', '#A1CAF1', '#BE0032', '#C2B280', '#848482', '#008856']
#
# Key: N
# Dictionary:
# data:    Var1         Var2      Freq    N
# 1     0  embryo_ctrl  0.005563    8
# 2     1  embryo_ctrl  0.236439  340
# 3     2  embryo_ctrl  0.000000    0
# 4     3  embryo_ctrl  0.383866  552
# 5     4  embryo_ctrl  0.000695    1
# ..  ...          ...       ...  ...
# 80   16       P2_mut  0.019455  232
# 81   17       P2_mut  0.035136  419
# 82   18       P2_mut  0.012998  155
# 83   19       P2_mut  0.009727  116
# 84   20       P2_mut  0.002683   32
#
# [84 rows x 4 columns]
# layers: o{'None': mapping: fill = ~Var2
# geom_bar: width = NULL, na.rm = FALSE, orientation = NA, flipped_aes = FALSE
# stat_identity: na.rm = FALSE
# position_dodge
# , }
# scales: <ggproto object: Class ScalesList, gg>
#     add: function
#     add_defaults: function
#     add_missing: function
#     backtransform_df: function
#     clone: function
#     find: function
#     get_scales: function
#     has_scale: function
#     input: function
#     map_df: function
#     n: function
#     non_position_scales: function
#     scales: list
#     train_df: function
#     transform_df: function
#     super:  <ggproto object: Class ScalesList, gg>
#
# mapping: o{'x': <quosure>
# expr: ^Var1
# env:  global
# , 'y': <quosure>
# expr: ^N
# env:  global
# , }
# theme: o{'axis.title.x': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': [1] "bold"
# , 'colour': [1] "black"
# , 'size': [14.], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, 'axis.title.y': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': [1] "bold"
# , 'colour': [1] "black"
# , 'size': [14.], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, 'axis.text.x': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': [1] "bold"
# , 'colour': [1] "black"
# , 'size': [12.], 'hjust': [1.], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': [45.], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, 'axis.text.y': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': [1] "bold"
# , 'colour': [1] "black"
# , 'size': [12.], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': [0.], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, 'legend.text': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': [1] "bold"
# , 'colour': [1] "black"
# , 'size': [12.], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, 'legend.title': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': [0.], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, 'legend.position': [1] "left"
# , 'panel.background': o{'fill': [1] "transparent"
# , 'colour': [1] "black"
# , 'size': [1.], 'linetype': [1] "solid"
# , 'inherit.blank': [1] FALSE
# , }, 'plot.title': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': [1] "bold.italic"
# , 'colour': [1] "black"
# , 'size': [16.], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, }
#
# Key: p1
# Dictionary:
# None: o{'plots': o{}, 'layout': o{'ncol': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'nrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'byrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'widths': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'heights': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'guides': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_level': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'design': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], }, 'annotation': o{'title': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'subtitle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'caption': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_levels': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_prefix': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_suffix': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_sep': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'theme': o{}, }, }
#
# Key: p2
# Dictionary:
# None: o{'plots': o{}, 'layout': o{'ncol': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'nrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'byrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'widths': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'heights': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'guides': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_level': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'design': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], }, 'annotation': o{'title': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'subtitle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'caption': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_levels': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_prefix': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_suffix': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_sep': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'theme': o{}, }, }
#
# Key: p3
# Dictionary:
# None: o{'plots': o{}, 'layout': o{'ncol': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'nrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'byrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'widths': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'heights': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'guides': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_level': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'design': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], }, 'annotation': o{'title': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'subtitle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'caption': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_levels': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_prefix': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_suffix': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_sep': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'theme': o{}, }, }
#
# Key: p5
# Dictionary:
# None: o{'plots': o{'None': o{'data':                     nFeature_RNA ident
# AAACAGCCAACTGGGA-4   1887.000014   RNA
# AAACAGCCAAGGATTA-3   3146.999994   RNA
# AAACAGCCAAGTTATC-3   2856.000004   RNA
# AAACAGCCAATTGAGA-4   1804.000006   RNA
# AAACAGCCACCTCAGG-4   1999.000004   RNA
# ...                          ...   ...
# TTTGTTGGTTAGCAGC-4   1595.000014   RNA
# TTTGTTGGTTAGTGAT-2    735.000007   RNA
# TTTGTTGGTTGCATCT-2    448.000006   RNA
# TTTGTTGGTTGGATAT-4   1705.999977   RNA
# TTTGTTGGTTTGCGCC-4   1720.999989   RNA
#
# [34264 rows x 2 columns], 'layers': o{'None': geom_violin: draw_quantiles = NULL, na.rm = FALSE, orientation = NA
# stat_ydensity: trim = TRUE, scale = width, na.rm = FALSE, orientation = NA, bounds = c(-Inf, Inf), adjust = 1
# position_dodge
# , }, 'scales': <ggproto object: Class ScalesList, gg>
#     add: function
#     add_defaults: function
#     add_missing: function
#     backtransform_df: function
#     clone: function
#     find: function
#     get_scales: function
#     has_scale: function
#     input: function
#     map_df: function
#     n: function
#     non_position_scales: function
#     scales: list
#     train_df: function
#     transform_df: function
#     super:  <ggproto object: Class ScalesList, gg>
# , 'guides': <Guides[0] ggproto object>
#
# <empty>
# , 'mapping': o{'x': <quosure>
# expr: ^ident
# env:  0x556aa54ab088
# , 'y': <quosure>
# expr: ^nFeature_RNA
# env:  0x556aa54ab088
# , 'fill': <quosure>
# expr: ^ident
# env:  0x556aa54ab088
# , }, 'theme': o{'line': o{'colour': [1] "black"
# , 'linewidth': [0.5], 'linetype': [1.], 'lineend': [1] "butt"
# , 'arrow': [1] FALSE
# , 'inherit.blank': [1] TRUE
# , }, 'rect': o{'fill': [1] NA
# , 'colour': [1] NA
# , 'linewidth': [0.5], 'linetype': [1.], 'inherit.blank': [1] TRUE
# , }, 'text': o{'family': [1] ""
# , 'face': [1] "plain"
# , 'colour': [1] "black"
# , 'size': [14.], 'hjust': [0.5], 'vjust': [0.5], 'angle': [0.], 'lineheight': [0.9], 'margin': [0. 0. 0. 0.], 'debug': [1] FALSE
# , 'inherit.blank': [1] TRUE
# , }, 'title': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'aspect.ratio': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.title': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.title.x': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': [1.], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [3.5 0.  0.  0. ], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.title.x.top': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': [0.], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0.  0.  3.5 0. ], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.title.x.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.title.y': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': [1.], 'angle': [90.], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0.  3.5 0.  0. ], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.title.y.left': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.title.y.right': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': [0.], 'angle': [-90.], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0.  0.  0.  3.5], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.text': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': [1] "black"
# , 'size': [12.], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.text.x': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': [1.], 'vjust': [1.], 'angle': [45.], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [3. 0. 0. 0.], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, 'axis.text.x.top': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': [0.], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0. 0. 3. 0.], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.text.x.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.text.y': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': [1.], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0. 3. 0. 0.], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.text.y.left': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.text.y.right': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': [0.], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0. 0. 0. 3.], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.text.theta': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.text.r': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': [0.5], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0.  2.8 0.  2.8], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'axis.ticks': o{'colour': [1] "black"
# , 'linewidth': [0.5], 'linetype': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineend': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'arrow': [1] FALSE
# , 'inherit.blank': [1] TRUE
# , }, 'axis.ticks.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.x.top': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.x.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.y.left': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.y.right': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.theta': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.r': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.x.top': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.x.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.y.left': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.y.right': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.theta': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.r': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.length': [3.5], 'axis.ticks.length.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.length.x.top': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.length.x.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.length.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.length.y.left': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.length.y.right': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.length.theta': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.ticks.length.r': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.length': [0.75], 'axis.minor.ticks.length.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.length.x.top': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.length.x.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.length.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.length.y.left': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.length.y.right': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.length.theta': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.minor.ticks.length.r': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.line': o{'colour': [1] "black"
# , 'linewidth': [0.5], 'linetype': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineend': [1] "square"
# , 'arrow': [1] FALSE
# , 'inherit.blank': [1] TRUE
# , }, 'axis.line.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.line.x.top': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.line.x.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.line.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.line.y.left': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.line.y.right': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.line.theta': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis.line.r': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.background': o{}, 'legend.margin': [0. 0. 0. 0.], 'legend.spacing': [14.], 'legend.spacing.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.spacing.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.key': o{}, 'legend.key.size': [15.4], 'legend.key.height': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.key.width': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.key.spacing': [7.], 'legend.key.spacing.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.key.spacing.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.frame': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.ticks': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.ticks.length': [0.2], 'legend.axis.line': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.text': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': [0.85714286], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'legend.text.position': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.title': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': [0.], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'legend.title.position': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.position': [1] "none"
# , 'legend.position.inside': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.direction': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.byrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.justification': [1] "left"   "center"
# , 'legend.justification.top': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.justification.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.justification.left': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.justification.right': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.justification.inside': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.location': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.box': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.box.just': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'legend.box.margin': [0. 0. 0. 0.], 'legend.box.background': o{}, 'legend.box.spacing': [14.], 'panel.background': o{}, 'panel.border': o{}, 'panel.spacing': [7.], 'panel.spacing.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'panel.spacing.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'panel.grid': o{}, 'panel.grid.major': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'panel.grid.minor': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'panel.grid.major.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'panel.grid.major.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'panel.grid.minor.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'panel.grid.minor.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'panel.ontop': [1] FALSE
# , 'plot.background': o{}, 'plot.title': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': [1] "bold"
# , 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': [1.14285714], 'hjust': [0.5], 'vjust': [1.], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0. 0. 7. 0.], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] FALSE
# , }, 'plot.title.position': [1] "panel"
# , 'plot.subtitle': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': [0.85714286], 'hjust': [0.], 'vjust': [1.], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [0. 0. 7. 0.], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'plot.caption': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': [0.78571429], 'hjust': [1.], 'vjust': [1.], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [7. 0. 0. 0.], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'plot.caption.position': [1] "panel"
# , 'plot.tag': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': [1] "bold"
# , 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': [0.], 'vjust': [0.7], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'plot.tag.position': [0. 1.], 'plot.tag.location': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'plot.margin': [7. 7. 7. 7.], 'strip.background': o{'fill': [1] "grey80"
# , 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'linewidth': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'linetype': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'strip.background.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'strip.background.y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'strip.clip': [1] "inherit"
# , 'strip.placement': [1] "inside"
# , 'strip.text': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': [0.85714286], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': [3.5 3.5 3.5 3.5], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'strip.text.x': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'strip.text.x.bottom': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'strip.text.x.top': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'strip.text.y': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': [-90.], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'strip.text.y.left': o{'family': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'face': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'colour': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'size': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'hjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'vjust': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'angle': [90.], 'lineheight': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'margin': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'debug': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'inherit.blank': [1] TRUE
# , }, 'strip.text.y.right': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'strip.switch.pad.grid': [3.5], 'strip.switch.pad.wrap': [3.5], }, 'coordinates': <ggproto object: Class CoordCartesian, Coord, gg>
#     aspect: function
#     backtransform_range: function
#     clip: on
#     default: TRUE
#     distance: function
#     expand: TRUE
#     is_free: function
#     is_linear: function
#     labels: function
#     limits: list
#     modify_scales: function
#     range: function
#     render_axis_h: function
#     render_axis_v: function
#     render_bg: function
#     render_fg: function
#     setup_data: function
#     setup_layout: function
#     setup_panel_guides: function
#     setup_panel_params: function
#     setup_params: function
#     train_panel_guides: function
#     transform: function
#     super:  <ggproto object: Class CoordCartesian, Coord, gg>
# , 'facet': <ggproto object: Class FacetNull, Facet, gg>
#     compute_layout: function
#     draw_back: function
#     draw_front: function
#     draw_labels: function
#     draw_panels: function
#     finish_data: function
#     init_scales: function
#     map_data: function
#     params: list
#     setup_data: function
#     setup_params: function
#     shrink: TRUE
#     train_scales: function
#     vars: function
#     super:  <ggproto object: Class FacetNull, Facet, gg>
# , 'plot_env': <environment: 0x556aa54ab088>
# , 'layout': <ggproto object: Class Layout, gg>
#     coord: NULL
#     coord_params: list
#     facet: NULL
#     facet_params: list
#     finish_data: function
#     get_scales: function
#     layout: NULL
#     map_position: function
#     panel_params: NULL
#     panel_scales_x: NULL
#     panel_scales_y: NULL
#     render: function
#     render_labels: function
#     reset_scales: function
#     resolve_label: function
#     setup: function
#     setup_panel_guides: function
#     setup_panel_params: function
#     train_position: function
#     super:  <ggproto object: Class Layout, gg>
# , 'labels': o{'y': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'x': [1] "Identity"
# , 'fill': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'title': [1] "nFeature_RNA"
# , }, }, }, 'layout': o{'ncol': [3.], 'nrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'byrow': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'widths': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'heights': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'guides': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_level': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axes': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'axis_titles': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'design': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], }, 'annotation': o{'title': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'subtitle': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'caption': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_levels': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_prefix': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_suffix': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'tag_sep': <rpy2.rinterface_lib.sexp.NULLType object at 0x7f433b9918d0> [0], 'theme': o{'legend.position': [1] "none"
# , }, }, }
#
# Key: pbmc_RNA
# R S4 Object
#
# Key: pbmc_RNA_prova
# R S4 Object
#
# Key: pbmc_umap_coord
# R S4 Object
#
# Key: PCA
# DataFrame:
#                        UMAP-1    UMAP-2             Barcode
# AAACAGCCAACTGGGA-4   8.262050  4.110445  AAACAGCCAACTGGGA-4
# AAACAGCCAAGGATTA-3   1.929796 -9.505244  AAACAGCCAAGGATTA-3
# AAACAGCCAAGTTATC-3  -3.871037 -9.753231  AAACAGCCAAGTTATC-3
# AAACAGCCAATTGAGA-4  10.093089  1.890220  AAACAGCCAATTGAGA-4
# AAACAGCCACCTCAGG-4   8.763607  3.744048  AAACAGCCACCTCAGG-4
#
# Key: test.use
# List:
# ['wilcox']
#
# Key: thresh.use
# NumPy Array:
# [0.25]
#
# Key: top10
# DataFrame:
#    p_val  avg_logFC  pct.1  pct.2  p_val_adj cluster     gene
# 1    0.0   1.748728  0.961  0.489        0.0       0    Unc5d
# 2    0.0   1.571726  0.845  0.230        0.0       0   Sema3c
# 3    0.0   1.350758  0.890  0.348        0.0       0  Galnt17
# 4    0.0   1.334421  0.902  0.421        0.0       0  Gramd1b
# 5    0.0   1.314171  0.967  0.612        0.0       0   Frmd4b
