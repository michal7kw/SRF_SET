# %%
import os
import tarfile
import scanpy as sc
import anndata as ad
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gzip
import scipy
import gc

# %%
# Set the working directory
working_dir = "/beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SET/GSE212252"
os.chdir(working_dir)
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /beegfs/scratch/ric.broccoli/kubacki.michal/SRF_SET/GSE212252

# %%
data_path = './DATA/POST_NATAL_CRE_NEGATIVE'
adata = sc.read_10x_mtx(
    data_path,
    var_names='gene_symbols',
    cache=True
)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 736156 × 32286
#     var: 'gene_ids', 'feature_types'

# %%
adata.obs.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACAGCCAAACAACA-1, AAACAGCCAAACATAG-1, AAACAGCCAAACCCTA-1, AAACAGCCAAACCTAT-1, AAACAGCCAAACCTTG-1]

# %%
adata.X
# Out:
# <736156x32286 sparse matrix of type '<class 'numpy.float32'>'
# 	with 57978799 stored elements in Compressed Sparse Column format>

# %%
non_zero_elements = adata.X.data[:10] if scipy.sparse.issparse(adata.X) else adata.X[np.nonzero(adata.X)][:10]

print("First 10 non-zero elements of adata.X:")
print(non_zero_elements)
# Out:
# First 10 non-zero elements of adata.X:
# [ 3.  1.  8. 11.  1.  1.  3.  8.  1.  1.]

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata.var['mt'] = adata.var_names.str.startswith('mt-')
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], inplace=True)

# %%
adata.var.head()
# Out:
#                    gene_ids    feature_types  n_cells     mt  \
# Xkr4     ENSMUSG00000051951  Gene Expression     8577  False
# Gm1992   ENSMUSG00000089699  Gene Expression      479  False
# Gm19938  ENSMUSG00000102331  Gene Expression     1703  False
# Gm37381  ENSMUSG00000102343  Gene Expression       27  False
# Rp1      ENSMUSG00000025900  Gene Expression      607  False
#
#          n_cells_by_counts  mean_counts  log1p_mean_counts  \
# Xkr4                  8577     0.621509           0.483357
# Gm1992                 479     0.009236           0.009194
# Gm19938               1703     0.036660           0.036004
# Gm37381                 27     0.000806           0.000806
# Rp1                    607     0.019967           0.019771
#
#          pct_dropout_by_counts  total_counts  log1p_total_counts
# Xkr4                 85.596252       37009.0           10.518944
# Gm1992               99.195593         550.0            6.311735
# Gm19938              97.140074        2183.0            7.688913
# Gm37381              99.954658          48.0            3.891820
# Rp1                  98.980637        1189.0            7.081708

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
adata = adata[adata.obs.n_genes_by_counts < 5000, :]
adata = adata[adata.obs.total_counts < 10000, :]
adata = adata[adata.obs.pct_counts_mt < 20, :]
gc.collect()
# Out:
# 26108

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# /home/kubacki.michal/.conda/envs/jupyter_nb/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:207: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# %%
sc.pp.pca(adata, n_comps=50)
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['n_genes_by_counts'], wspace=0.4)

# %%
adata.write('./output/processed_post_natal_cre_negative_data.h5ad')
